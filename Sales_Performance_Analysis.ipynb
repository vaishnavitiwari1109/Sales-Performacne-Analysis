# %% [markdown]
# ## Data Loading and Exploration

# %%
from google.colab import files
uuploaded = files.upload()
# Out:
#      <input type="file" id="files-bec3c29a-3d18-41d7-abfb-42e07c3987b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bec3c29a-3d18-41d7-abfb-42e07c3987b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #### Read the dataset

# %%
import pandas as pd

df = pd.read_csv('superstore_final_dataset (1).csv', encoding='latin1')

# %% [markdown]
# #### Checking First 5 Rows

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# #### Checking Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   object
#  3   Ship_Date      9800 non-null   object
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %% [markdown]
# #### Checking Shape

# %%
print(df.shape)
# Out:
# (9800, 18)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# #### Checking Duplicate Values

# %%
# check if duplicate value exist

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# if dupliicate value exist

df = df.drop_duplicates()

# %% [markdown]
# #### Checking Column Names

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales'],
#       dtype='object')

# %% [markdown]
# #### Statistical Summary

# %%
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# #### Converting Date Column

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], dayfirst=True)

# %% [markdown]
# #### Creating month & year columns

# %%
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month_name()

# %% [markdown]
# OBSERVATIONS
#
# 1. The dataset contains 9,800 sales records and 18 columns related to orders, customers, products, regions, and sales.
#
# 2. No duplicate records were found in the dataset, ensuring data consistency.
#
# 3. Only the Postal_Code column contains 11 missing values, while all other columns are complete.
#
# 4. The sales data covers multiple product categories, customer segments, and regions across the United States.
#
# 5. The average sales value per transaction varies significantly, indicating the presence of both low-value and high-value orders.
#
# 6. Sales performance differs across regions and categories, suggesting opportunities for targeted business strategies.
#
# 7. The dataset contains sufficient information to analyze sales trends, regional performance, and product-level performance.

# %% [markdown]
# ## Creating KPIs

# %% [markdown]
# #### KPI 1:  Revenue (Total Sales)

# %%
total_revenue = df['Sales'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 2261536.7827000003

# %% [markdown]
# #### KPI 2: Total Orders

# %%
total_orders = df['Order_ID'].nunique()

print("Total Orders:", total_orders)
# Out:
# Total Orders: 4922

# %% [markdown]
# #### KPI 3: Average Order Value (AOV)

# %%
aov = total_revenue / total_orders

print("Average Order Value:", round(aov,2))
# Out:
# Average Order Value: 459.48

# %% [markdown]
# #### KPI Summary

# %%
total_revenue = df['Sales'].sum()

total_orders = df['Order_ID'].nunique()

aov = total_revenue / total_orders

print("Total Revenue =", round(total_revenue,2))
print("Total Orders =", total_orders)
print("Average Order Value =", round(aov,2))
# Out:
# Total Revenue = 2261536.78
# Total Orders = 4922
# Average Order Value = 459.48

# %% [markdown]
# Observation
#
# The dataset generated a substantial amount of revenue, indicating strong overall sales performance across products and regions.
# A large number of unique orders were recorded, reflecting consistent customer purchasing activity.
# The Average Order Value (AOV) provides insight into customer spending behavior and indicates the average revenue generated per transaction.
# The dataset does not contain profit-related information; therefore, Profit Margin could not be calculated.
# Conversion metrics could not be evaluated because the dataset does not include website traffic, visitor, lead, or conversion-related data.

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### Sales by Region

# %%
import matplotlib.pyplot as plt

region_sales = df.groupby('Region')['Sales'].sum().sort_values()

region_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# Observation
#
# Sales performance varies across regions, with some regions contributing significantly more revenue than others. This indicates opportunities for region-specific marketing and sales strategies.

# %% [markdown]
# #### Sales by Category

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# Observation
#
# The sales distribution among categories is uneven, suggesting that customer demand is stronger for certain product categories. These categories contribute a larger share of overall revenue.

# %% [markdown]
# #### Top 10 Products

# %%
top_products = df.groupby('Product_Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='barh')
plt.title("Top 10 Products")
plt.show()

# %% [markdown]
# Observation
#
# A small number of products generate a significant portion of total sales revenue. These products can be considered key revenue drivers and should receive additional business focus.

# %% [markdown]
# #### Monthly Sales Trend

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], dayfirst=True)

df['Month'] = df['Order_Date'].dt.month_name()

monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.show()

# %% [markdown]
# Observation
#
# Sales fluctuate across different months, indicating variations in customer demand over time. Seasonal patterns may influence purchasing behavior and sales performance.

# %% [markdown]
# ####

# %% [markdown]
# KEY INSIGHTS
#
# 1. Sales are not evenly distributed across regions, with some regions contributing significantly more revenue than others.
#
# 2. Certain product categories generate a larger share of total sales, indicating stronger customer demand.
#
# 3. A small number of products contribute a substantial portion of total revenue, making them key revenue drivers.
#
# 4. Several products consistently generate low sales and may require promotional efforts or product strategy adjustments.
#
# 5. Monthly sales trends indicate fluctuations in customer demand, suggesting the presence of seasonal buying patterns.
#
# 6. Customer purchasing behavior varies across segments, highlighting opportunities for segment-specific marketing campaigns.
#
# 7. Regional performance differences suggest that localized marketing and sales strategies could improve overall business results.

# %% [markdown]
# RECOMMENDATIONS
#
# 1. Increase marketing investment in top-performing products and categories to maximize revenue growth.
#
# 2. Implement targeted promotional campaigns for low-performing products to improve visibility and sales.
#
# 3. Develop region-specific sales and advertising strategies to improve performance in underperforming regions.
#
# 4. Use historical sales trends to forecast demand and optimize inventory planning during peak periods.
#
# 5. Regularly monitor product performance and customer preferences to support data-driven business decisions.
#
# 6. Introduce bundle offers and cross-selling strategies to increase average order value.
#
# 7. Strengthen customer engagement through personalized promotions based on purchasing behavior.

# %% [markdown]
# Conclusion
#
# This sales performance analysis provided valuable insights into regional sales distribution, product performance, and overall revenue trends. The dataset was successfully cleaned and analyzed to identify key business patterns and opportunities. The findings reveal significant differences in sales performance across regions, categories, and products. By focusing on high-performing products, improving low-performing areas, and adopting data-driven marketing and inventory strategies, Alfido Tech can enhance customer engagement, increase sales performance, and support long-term business growth.
